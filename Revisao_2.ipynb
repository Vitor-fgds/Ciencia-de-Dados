# %% [markdown]
# Lista de Exercícios - Revisão do conteúdo do curso Pandas do Kaggle 02.
#
# Os exercícios a seguir foram baseados nos conteúdos apresentados no curso Pandas do Kaggle que vocês fizeram para a prova.

# %% [markdown]
# 01) Carregue o arquivo GSAF5.xls.csv em uma variável denominada df definindo a primeira coluna do arquivo como o índice das linhas.
#
# Obs: O arquivo "GSAF5.xls.csv" pode ser encontrado em [Shark Attacks](https://www.kaggle.com/datasets/thedevastator/shark-attacks-the-risks-of-coastal-water-activit)

# %%
import pandas as pd
df = pd.read_csv('/content/GSAF5.xls.csv', index_col = 0)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (10,17,18,19,20,21,24) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# 02) Imprima as 8 primeiras linhas do DataFrame df.

# %%
df.head(8)
# Out:
#         Case Number                  Date    Year        Type      Country  \
# index
# 0        2020.02.05           05-Feb-2020  2020.0  Unprovoked          USA
# 1      2020.01.30.R  Reported 30-Jan-2020  2020.0    Provoked      BAHAMAS
# 2        2020.01.17           17-Jan-2020  2020.0  Unprovoked    AUSTRALIA
# 3        2020.01.16           16-Jan-2020  2020.0  Unprovoked  NEW ZEALAND
# 4        2020.01.13           13-Jan-2020  2020.0  Unprovoked          USA
# 5        2020.01.12           12-Jan-2020  2020.0  Unprovoked     THAILAND
# 6        2020.01.07           07-Jan-2020  2020.0  Unprovoked    AUSTRALIA
# 7        2020.01.05           05-Jan-2020  2020.0  Unprovoked    AUSTRALIA
#
#                      Area                 Location                  Activity  \
# index
# 0                    Maui                      NaN  Stand-Up Paddle boarding
# 1                  Exumas                      NaN                  Floating
# 2         New South Wales            Windang Beach                   Surfing
# 3               Southland              Oreti Beach                   Surfing
# 4          North Carolina    Rodanthe, Dare County                   Surfing
# 5      Phang Nga Province         Nang Thong Beach                  Swimming
# 6              Queensland        North West Island                  Swimming
# 7       Western Australia  Cull Island / Esperance              Scuba diving
#
#                     Name Unnamed: 9  ... Unnamed: 246 Unnamed: 247  \
# index                                ...
# 0                    NaN        NaN  ...          NaN          NaN
# 1        Ana Bruna Avila          F  ...          NaN          NaN
# 2         Will Schroeter          M  ...          NaN          NaN
# 3            Jordan King          F  ...          NaN          NaN
# 4           Samuel Horne          M  ...          NaN          NaN
# 5      Hans-Peter Malten          M  ...          NaN          NaN
# 6            Miah Holmes          F  ...          NaN          NaN
# 7           Gary Johnson          M  ...          NaN          NaN
#
#       Unnamed: 248 Unnamed: 249 Unnamed: 250 Unnamed: 251 Unnamed: 252  \
# index
# 0              NaN          NaN          NaN          NaN          NaN
# 1              NaN          NaN          NaN          NaN          NaN
# 2              NaN          NaN          NaN          NaN          NaN
# 3              NaN          NaN          NaN          NaN          NaN
# 4              NaN          NaN          NaN          NaN          NaN
# 5              NaN          NaN          NaN          NaN          NaN
# 6              NaN          NaN          NaN          NaN          NaN
# 7              NaN          NaN          NaN          NaN          NaN
#
#       Unnamed: 253 Unnamed: 254 Unnamed: 255
# index
# 0              NaN          NaN          NaN
# 1              NaN          NaN          NaN
# 2              NaN          NaN          NaN
# 3              NaN          NaN          NaN
# 4              NaN          NaN          NaN
# 5              NaN          NaN          NaN
# 6              NaN          NaN          NaN
# 7              NaN          NaN          NaN
#
# [8 rows x 256 columns]

# %% [markdown]
# 03) Apresente a contagem de acidentes que acontenceram em cada pais. Ordene o resultado pela coluna pais de forma descendente.

# %%
df.groupby('Country').Type.count().sort_values(ascending=False)
# Out:
# Country
# USA                         2310
# AUSTRALIA                   1373
# SOUTH AFRICA                 585
# PAPUA NEW GUINEA             135
# NEW ZEALAND                  135
#                             ...
# OCEAN                          1
# NORTHERN MARIANA ISLANDS       1
# NORTHERN ARABIAN SEA           1
# NORTH SEA                      1
# ADMIRALTY ISLANDS              1
# Name: Type, Length: 205, dtype: int64

# %% [markdown]
# 04) Qual a atividade que mais gera acidentes com tubarões?

# %%
x = df[df['Type'] == 'Provoked']
x.groupby('Activity').Type.count().sort_values(ascending=False)
# Out:
# Activity
# Fishing                                          185
# Spearfishing                                      53
# Shark fishing                                     14
# Surfing                                           13
# Diving                                            13
#                                                 ...
# Fishing inside net                                 1
# Fishing, attempted to take a netted shark          1
# Fishing, caught a 15' shark & took it onboard      1
# Fishing, hauling in a set line                     1
# Watercraft                                         1
# Name: Type, Length: 225, dtype: int64

# %% [markdown]
# 05) É possível descobrir se existe alguma pessoa nesta base de dados que já tenha sofrido mais de um acidente com tubarões?

# %%
x = df[df['Type'] == 'Provoked']
x.groupby('Name').Type.count().sort_values(ascending=False)
# Out:
# Name
# male                 57
# female                6
# boy                   4
# fisherman             3
# boat                  2
#                      ..
# Gerald Gaskins        1
# George Vanderbilt     1
# George Sohswel        1
# George Roberts        1
# surf patrol boat      1
# Name: Type, Length: 515, dtype: int64

# %% [markdown]
# 06) Quantos casos de Data Frame não possuem cadastro para a coluna 'Location'?

# %%
?

# %% [markdown]
# 07) Qual o tipo de dados da coluna Year?

# %%
df.Year.dtype
# Out:
# dtype('float64')

# %% [markdown]
# 08) Converta a coluna Year para int64. Sugestão: O parâmetro inplace pode ser utilizado para que a conversão seja gravada no Data Frame.

# %%
?

# %% [markdown]
# 09) Preencha todas as células vazias (NaN) da coluna Location com o termo 'Desconhecido'.

# %%
df.Location.fillna('Desconhecido')
# Out:
# index
# 0                              Desconhecido
# 1                              Desconhecido
# 2                             Windang Beach
# 3                               Oreti Beach
# 4                     Rodanthe, Dare County
#                        ...
# 6457                            Roebuck Bay
# 6458                           Desconhecido
# 6459                         Ocracoke Inlet
# 6460                   Panama Bay 8ºN, 79ºW
# 6461    Below the English fort, Trincomalee
# Name: Location, Length: 6462, dtype: object

# %% [markdown]
# 10) Faça a tradução da coluna Type substituindo os termos em inflês por seus respectivos termos em português.

# %%
?

# %% [markdown]
# 11) Renomeie a coluna 'Unnamed: 9' para 'Sexo'.

# %%
df.rename(columns={'Unnamed: 9' : 'Sexo'})
# Out:
#         Case Number                  Date    Year        Type  \
# index
# 0        2020.02.05           05-Feb-2020  2020.0  Unprovoked
# 1      2020.01.30.R  Reported 30-Jan-2020  2020.0    Provoked
# 2        2020.01.17           17-Jan-2020  2020.0  Unprovoked
# 3        2020.01.16           16-Jan-2020  2020.0  Unprovoked
# 4        2020.01.13           13-Jan-2020  2020.0  Unprovoked
# ...             ...                   ...     ...         ...
# 6457        ND.0005           Before 1903     0.0  Unprovoked
# 6458        ND.0004           Before 1903     0.0  Unprovoked
# 6459        ND.0003             1900-1905     0.0  Unprovoked
# 6460        ND.0002             1883-1889     0.0  Unprovoked
# 6461        ND.0001             1845-1853     0.0  Unprovoked
#
#                   Country               Area  \
# index
# 0                     USA               Maui
# 1                 BAHAMAS             Exumas
# 2               AUSTRALIA    New South Wales
# 3             NEW ZEALAND          Southland
# 4                     USA     North Carolina
# ...                   ...                ...
# 6457            AUSTRALIA  Western Australia
# 6458            AUSTRALIA  Western Australia
# 6459                  USA     North Carolina
# 6460               PANAMA                NaN
# 6461   CEYLON (SRI LANKA)   Eastern Province
#
#                                   Location                  Activity  \
# index
# 0                                      NaN  Stand-Up Paddle boarding
# 1                                      NaN                  Floating
# 2                            Windang Beach                   Surfing
# 3                              Oreti Beach                   Surfing
# 4                    Rodanthe, Dare County                   Surfing
# ...                                    ...                       ...
# 6457                           Roebuck Bay                    Diving
# 6458                                   NaN              Pearl diving
# 6459                        Ocracoke Inlet                  Swimming
# 6460                  Panama Bay 8ºN, 79ºW                       NaN
# 6461   Below the English fort, Trincomalee                  Swimming
#
#                         Name Sexo  ... Unnamed: 246 Unnamed: 247 Unnamed: 248  \
# index                              ...
# 0                        NaN  NaN  ...          NaN          NaN          NaN
# 1            Ana Bruna Avila    F  ...          NaN          NaN          NaN
# 2             Will Schroeter    M  ...          NaN          NaN          NaN
# 3                Jordan King    F  ...          NaN          NaN          NaN
# 4               Samuel Horne    M  ...          NaN          NaN          NaN
# ...                      ...  ...  ...          ...          ...          ...
# 6457                    male  NaN  ...          NaN          NaN          NaN
# 6458                   Ahmun  NaN  ...          NaN          NaN          NaN
# 6459   Coast Guard personnel  NaN  ...          NaN          NaN          NaN
# 6460         Jules Patterson  NaN  ...          NaN          NaN          NaN
# 6461                    male  NaN  ...          NaN          NaN          NaN
#
#       Unnamed: 249 Unnamed: 250 Unnamed: 251 Unnamed: 252 Unnamed: 253  \
# index
# 0              NaN          NaN          NaN          NaN          NaN
# 1              NaN          NaN          NaN          NaN          NaN
# 2              NaN          NaN          NaN          NaN          NaN
# 3              NaN          NaN          NaN          NaN          NaN
# 4              NaN          NaN          NaN          NaN          NaN
# ...            ...          ...          ...          ...          ...
# 6457           NaN          NaN          NaN          NaN          NaN
# 6458           NaN          NaN          NaN          NaN          NaN
# 6459           NaN          NaN          NaN          NaN          NaN
# 6460           NaN          NaN          NaN          NaN          NaN
# 6461           NaN          NaN          NaN          NaN          NaN
#
#       Unnamed: 254 Unnamed: 255
# index
# 0              NaN          NaN
# 1              NaN          NaN
# 2              NaN          NaN
# 3              NaN          NaN
# 4              NaN          NaN
# ...            ...          ...
# 6457           NaN          NaN
# 6458           NaN          NaN
# 6459           NaN          NaN
# 6460           NaN          NaN
# 6461           NaN          NaN
#
# [6462 rows x 256 columns]
