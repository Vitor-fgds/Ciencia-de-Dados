# %%
import pandas as pd

# %%
netflix = pd.read_csv('/content/netflix.csv')

# %%
netflix
# Out:
#            As of  Rank Year to Date Rank Last Week Rank  \
# 0     2020-04-01     1                 1              1
# 1     2020-04-01     2                 2              -
# 2     2020-04-01     3                 3              2
# 3     2020-04-01     4                 4              -
# 4     2020-04-01     5                 5              4
# ...          ...   ...               ...            ...
# 7095  2022-03-11     6                 5              1
# 7096  2022-03-11     7                 7              2
# 7097  2022-03-11     8                 8              -
# 7098  2022-03-11     9                 9              7
# 7099  2022-03-11    10                10              -
#
#                              Title     Type Netflix Exclusive  \
# 0     Tiger King: Murder, Mayhem …  TV Show               Yes
# 1                            Ozark  TV Show               Yes
# 2                     All American  TV Show               NaN
# ...

# %% [markdown]
# 1) Apresente um resumo geral descrevendo os dados apresentados nesta base de dados (BD):
#
# **Resposta:** A tabela apresenta dados e informações do "TOP 10" diário da Netflix.
#
# 2) Analise e explique de que dado se trata cada coluna deste BD:
#
# **As of:** Esta coluna indica a data que foram coletados os dados do filme/serie;
#
# **Rank:** Mostra o rank que o filme/serie assumiu no dia em que o dado foi coletado;
#
# **Year to Date Rank:** Mostra o rank obtido pelo filme/serie no dia anterior da coleta de dados;
#
# **Last Week Rank:** Rank da semana passada;
#
# **Title:** Nome da serie/filme;
#
# **Type:** Informa se a obra é um filme ou serie;
#
# **Netflix Exlusive:** Informa se o filme é exclusivo da Netflix;
#
# **Netflix Release Date:** Data de lançamento da obra na Netflix;
#
# **Days in Top 10:** Dias que a obra ficou no TOP 10;
#
# **Viewership Score:** Número de visualizações.

# %%
netflix
# Out:
#            As of  Rank Year to Date Rank Last Week Rank  \
# 0     2020-04-01     1                 1              1
# 1     2020-04-01     2                 2              -
# 2     2020-04-01     3                 3              2
# 3     2020-04-01     4                 4              -
# 4     2020-04-01     5                 5              4
# ...          ...   ...               ...            ...
# 7095  2022-03-11     6                 5              1
# 7096  2022-03-11     7                 7              2
# 7097  2022-03-11     8                 8              -
# 7098  2022-03-11     9                 9              7
# 7099  2022-03-11    10                10              -
#
#                              Title     Type Netflix Exclusive  \
# 0     Tiger King: Murder, Mayhem …  TV Show               Yes
# 1                            Ozark  TV Show               Yes
# 2                     All American  TV Show               NaN
# ...

# %% [markdown]
# 3) O chefe da empresa detentora deste BD espera que você possa utilizar seus conhecimentos para explorar este BD e apontar afirmações que auxilie em tomadas de decisões futuras da empresa para alcançar melhores resultados financeiros. Traga pelo menos 5 afirmações. Tente coletar as afirmações mais importantes para a empresa. Você pode fazer pesquisas de dados fora deste BD para auxiliar em suas afirmações.

# %% [markdown]
# **A obra que ficou mais dias no "TOP 10"**

# %%
netflix.loc[netflix['Days In Top 10'] == netflix['Days In Top 10'].max()]
# Out:
#            As of  Rank Year to Date Rank Last Week Rank      Title     Type  \
# 6998  2022-03-01     9                 -              -  Cocomelon  TV Show
#
#      Netflix Exclusive Netflix Release Date  Days In Top 10  Viewership Score
# 6998               NaN          Jun 1, 2020             428              1474

# %% [markdown]
# **Obra mais assistida**

# %%
netflix.loc[netflix['Viewership Score'] == netflix['Viewership Score'].max()]
# Out:
#            As of  Rank Year to Date Rank Last Week Rank      Title     Type  \
# 6998  2022-03-01     9                 -              -  Cocomelon  TV Show
#
#      Netflix Exclusive Netflix Release Date  Days In Top 10  Viewership Score
# 6998               NaN          Jun 1, 2020             428              1474

# %% [markdown]
# **Tipo de obras mais assistido**

# %%
netflix.value_counts('Type')
# Out:
# Type
# TV Show            4446
# Movie              2611
# Stand-Up Comedy      41
# Concert/Perf…         2
# dtype: int64

# %% [markdown]
# **Obra exclusiva da Netflix mais assistido**

# %%
netflix_exclusive = netflix.loc[netflix['Netflix Exclusive'] == 'Yes']
netflix_exclusive.loc[netflix_exclusive['Viewership Score'] == netflix_exclusive['Viewership Score'].max()]
# Out:
#            As of  Rank Year to Date Rank Last Week Rank  Title     Type  \
# 6996  2022-03-01     7                 7              8  Ozark  TV Show
#
#      Netflix Exclusive Netflix Release Date  Days In Top 10  Viewership Score
# 6996               Yes         Jul 21, 2017              89               536

# %% [markdown]
# **Filme mais assistido**

# %%
filmes = netflix.loc[netflix['Type'] == 'Movie']
filmes.loc[netflix_exclusive['Viewership Score'] == netflix_exclusive['Viewership Score'].max()]
# Out:
#           As of  Rank Year to Date Rank Last Week Rank     Title   Type  \
# 959  2020-07-05    10                10              4  365 Days  Movie
#
#     Netflix Exclusive Netflix Release Date  Days In Top 10  Viewership Score
# 959               Yes          Jul 7, 2020              28               213
